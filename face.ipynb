# %%
import dlib
import face_recognition
import cv2
import numpy

# %%
import dlib
import face_recognition
import cv2
import numpy
print("Все библиотеки установлены правильно!")
# Out:
# Все библиотеки установлены правильно!

# %%
import cv2

video_capture = cv2.VideoCapture(0)

if not video_capture.isOpened():
    print("Ошибка: Камера не открылась!")
else:
    print("Камера открылась успешно!")

video_capture.release()
# Out:
# Камера открылась успешно!
